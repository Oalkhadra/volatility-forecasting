# %%
from thetadata import ThetaClient
import datetime as dt

# Initialize with your credentials
client = ThetaClient(username="omar.alkhadra@outlook.com", passwd="pTD!7g5g3fy6vM4")

# Connect and query
with client.connect():
    # Get SPY option chain
    data = client.get_hist_option(
        req=OptionReqType.QUOTE,
        root="SPY",
        exp=dt.date(2024, 12, 20),  # Pick a valid expiration
        strike=450000,  # Strike in thousandths (450.000 = $450)
        right=OptionRight.CALL,
        date_range=DateRange(dt.date(2024, 12, 1), dt.date(2024, 12, 7))
    )
    
    print(data)
# Out:
# If you require API support, feel free to join our discord server! http://discord.thetadata.us
# [12-07-2025 16:58:27] INFO: Starting Theta Terminal v1.8.6 Revision A...
# [12-07-2025 16:58:27] INFO: Using /home/oalkhadra/ThetaData/ThetaTerminal/logs as the log directory
# [12-07-2025 16:58:27] INFO: Using /home/oalkhadra/ThetaData/ThetaTerminal/config_0.properties as the config file
# [12-07-2025 16:58:27] WARN: Configuration file not found: created a default config file.
# Exception in thread "Thread-3" java.lang.RuntimeException: java.io.IOException: Failed to bind to 0.0.0.0/0.0.0.0:25520
# 	at net.thetadata.terminal.http.WSServer.lambda$new$0(WSServer.java:30)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: java.io.IOException: Failed to bind to 0.0.0.0/0.0.0.0:25520
# 	at org.eclipse.jetty.server.ServerConnector.openAcceptChannel(ServerConnector.java:349)
# 	at org.eclipse.jetty.server.ServerConnector.open(ServerConnector.java:310)
# ...

# %%
pip install httpx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 1.7 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 KB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 KB 6.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
